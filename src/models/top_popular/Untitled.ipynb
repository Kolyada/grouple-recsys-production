# %%
import pandas as pd

# %%
path = '/data/groupLe_recsys/processed/dorama/views_little.csv'
df = pd.read_csv(path)
df.head(4)
# Out:
#    item_id  rate  user_id
# 0        3  10.0    21596
# 1        3  10.0    95282
# 2        3  10.0    59972
# 3        3   9.0    48468

# %%
df[df.user_id == 21596]
# Out:
#          item_id  rate  user_id
# 0              3  10.0    21596
# 138662        16  10.0    21596
# 158459        18  10.0    21596
# 186670        21  10.0    21596
# 303956        37   9.0    21596
# ...          ...   ...      ...
# 6924923     4963   0.0    21596
# 7014608     4991   0.0    21596
# 7111260     5067   0.0    21596
# 7863492     5523   0.0    21596
# 7873045     5528   0.0    21596
#
# [260 rows x 3 columns]

# %%
df[df.user_id == 21596]['item_id'].tolist()
# Out:
# [3,
#  16,
#  18,
#  21,
#  37,
#  39,
#  45,
#  46,
#  50,
#  56,
#  58,
#  59,
#  61,
#  74,
#  79,
#  86,
#  87,
#  98,
#  104,
#  108,
#  109,
#  121,
#  125,
#  133,
#  134,
#  168,
#  179,
#  181,
#  184,
#  198,
#  203,
#  207,
#  224,
#  225,
#  226,
#  227,
#  235,
#  236,
#  247,
#  265,
#  269,
#  274,
#  290,
#  291,
#  309,
#  312,
#  326,
#  335,
#  343,
#  363,
#  364,
#  369,
#  428,
#  473,
#  512,
#  524,
#  539,
#  560,
#  564,
#  592,
#  605,
#  608,
#  611,
#  615,
#  624,
#  687,
#  715,
#  717,
#  728,
#  732,
#  739,
#  746,
#  747,
#  759,
#  761,
#  807,
#  814,
#  816,
#  817,
#  818,
#  827,
#  830,
#  846,
#  909,
#  912,
#  917,
#  925,
#  954,
#  971,
#  994,
#  1021,
#  1027,
#  1028,
#  1057,
#  1058,
#  1097,
#  1135,
#  1153,
#  1164,
#  1173,
#  1184,
#  1186,
#  1189,
#  1204,
#  1213,
#  1219,
#  1220,
#  1224,
#  1273,
#  1281,
#  1300,
#  1306,
#  1352,
#  1357,
#  1363,
#  1367,
#  1380,
#  1381,
#  1399,
#  1429,
#  1432,
#  1469,
#  1480,
# ...
